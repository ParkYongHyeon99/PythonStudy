# %%
import my_utils2 as mu
import requests
import random
import pandas as pd
from tqdm import tqdm

# %%
import requests
import random
import pandas as pd
from tqdm import tqdm

# %%
df = mu.get_rawdata('GOLD')
# Out:
# get summonerId....
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:06<00:00,  1.57s/it]
# get puuId.....
# 100%|██████████████████████████████████████████████████████████████████████████████████| 12/12 [00:16<00:00,  1.36s/it]
# get match_id....
# 100%|██████████████████████████████████████████████████████████████████████████████████| 12/12 [00:16<00:00,  1.41s/it]
# get matches & timeline....
# 100%|██████████████████████████████████████████████████████████████████████████████████| 36/36 [02:01<00:00,  3.38s/it]

# %%
df.iloc[0].matches['info']['gameVersion']
# Out:
# '13.24.547.9214'

# %%
# Out:
# 'lIlIIllllIllIlll'

# %%
df.iloc[0].matches['info']['participants'][0]['item0']
# Out:
# 6672

# %% [markdown]
# # raw_data를 바탕으로 한 소환사당 한컬럼을 차지하는 데이터프레임 생성

# %% [markdown]
# # matchId, gameDuration, gameVersion, /riotIdGameName,riotIdTagline, summonerLevel, participantId, championName, champExperience, teamPosition, teamId, win, kills, deaths, assists, totalDamageDealtToChampions, totalDamageTaken

# %%
df.iloc[0].matches['info']['participants'][j]['riotIdGameName']
# Out:
# 'lIlIIllllIllIlll'

# %%
df_creates = []
for i in range(len(df)): 
    match_id = df.iloc[i]['match_id']
    gameDuration = df.iloc[i].matches['info']['gameDuration']
    gameVersion = df.iloc[i].matches['info']['gameVersion']
    match =  df.iloc[i].matches['info']['participants']

    for j in range(len(df.iloc[i].matches['info']['participants'])):
        
        try:
            riotIdGameName = match[j]['riotIdGameName'] 
        except:
            riotIdGameName = ''
        try:
            riotIdTagline = match[j]['riotIdTagline']
        except:
            riotIdTagline = ''
        summonerLevel = df.iloc[i].matches['info']['participants'][j]['summonerLevel']
        participantId = df.iloc[i].matches['info']['participants'][j]['participantId']
        championName = df.iloc[i].matches['info']['participants'][j]['championName']
        champExperience = df.iloc[i].matches['info']['participants'][j]['champExperience']
        teamPosition = df.iloc[i].matches['info']['participants'][j]['teamPosition']
        teamId = df.iloc[i].matches['info']['participants'][j]['teamId']
        win = df.iloc[i].matches['info']['participants'][j]['win']
        kills = df.iloc[i].matches['info']['participants'][j]['kills']
        deaths = df.iloc[i].matches['info']['participants'][j]['deaths']
        assists = df.iloc[i].matches['info']['participants'][j]['assists']
        totalDamageDealtToChampions = df.iloc[i].matches['info']['participants'][j]['totalDamageDealtToChampions']
        totalDamageTaken = df.iloc[i].matches['info']['participants'][j]['totalDamageTaken']
        
        df_creates.append([match_id, gameDuration, gameVersion, riotIdGameName, riotIdTagline,summonerLevel, participantId, championName, champExperience, teamPosition, teamId, win, kills, deaths, assists, totalDamageDealtToChampions, totalDamageTaken])
        
columns =[['gameId', 'gameDuration', 'gameVersion', 'riotIdGameName','riotIdTagline', 'summonerLevel', 'participantId', 'championName', 'champExperience', 'teamPosition', 'teamId', 'win', 'kills', 'deaths', 'assists', 'totalDamageDealtToChampions', 'totalDamageTaken']]
df3 = pd.DataFrame(df_creates, columns = columns)

# %%
df_creates = []
for i in range(len(df)): 
    match =  df.iloc[i].matches['info']['participants']

    for j in range(len(match)):
        match_id = df.iloc[i].match_id
        gameDuration = df.iloc[i].matches['info']['gameDuration']
        gameVersion = df.iloc[i].matches['info']['gameVersion']
        
        try:
            riotIdGameName = match[j]['riotIdGameName'] 
        except:
            riotIdGameName = ''
        try:
            riotIdTagline = match[j]['riotIdTagline']
        except:
            riotIdTagline = ''
        summonerLevel = match[j]['summonerLevel']

        participantId = match[j]['participantId']

        championName = match[j]['championName']

        champExperience = match[j]['champExperience']

        teamPosition = match[j]['teamPosition']

        teamId = match[j]['teamId']

        win = match[j]['win']

        kills = match[j]['kills']

        deaths = match[j]['deaths']

        assists = match[j]['assists']

        totalDamageDealtToChampions = match[j]['totalDamageDealtToChampions']

        totalDamageTaken = match[j]['totalDamageTaken']
        
        df_creates.append([match_id, gameDuration, gameVersion, riotIdGameName, riotIdTagline,summonerLevel, participantId, championName, champExperience, teamPosition, teamId, win, kills, deaths, assists, totalDamageDealtToChampions, totalDamageTaken])
        
        
columns =['matchId', 'gameDuration', 'gameVersion', 'riotIdGameName','riotIdTagline', 'summonerLevel', 'participantId', 'championName', 'champExperience', 'teamPosition', 'teamId', 'win', 'kills', 'deaths', 'assists', 'totalDamageDealtToChampions', 'totalDamageTaken']
df2 = pd.DataFrame(df_creates, columns = columns)

# %%
df2
# Out:
#            matchId  gameDuration     gameVersion    riotIdGameName  \
# 0    KR_6857894499          1747  13.24.547.9214  lIlIIllllIllIlll
# 1    KR_6857894499          1747  13.24.547.9214            손가락 없음
# 2    KR_6857894499          1747  13.24.547.9214          해양동의몰락한왕
# 3    KR_6857894499          1747  13.24.547.9214          장충동왕족발보쌈
# 4    KR_6857894499          1747  13.24.547.9214            약속한것처럼
# ..             ...           ...             ...               ...
# 355  KR_6741424560          1433  13.19.534.5972
# 356  KR_6741424560          1433  13.19.534.5972
# 357  KR_6741424560          1433  13.19.534.5972
# 358  KR_6741424560          1433  13.19.534.5972
# 359  KR_6741424560          1433  13.19.534.5972
#
#     riotIdTagline  summonerLevel  participantId championName  champExperience  \
# 0             KR1             61              1         Yone            13483
# 1             KR1            435              2      Shyvana            20257
# ...

# %%
df.iloc[0].timelines['info']['frames'][30]['participantFrames']['1']['totalGold']
# Out:
# 11469

# %% [markdown]
# # matchid, participantsid, g5~15분 데이터프레임만들기

# %%
columns = ['matchId','participantId','g5','g6','g7','g8','g9']

# %%
lst = []
for i in range(len(df)):
    timeline = df.iloc[i].timelines['info']['frames'][0]['participantFrames']
    for j in range(len(timeline)):
        tmp = []
        match_id = df.iloc[i].match_id
        tmp.append(match_id)
        participants_id = df.iloc[i].timelines['info']['participants'][j]['participantId']
        tmp.append(participants_id)
        for k in range(5, 10):
            tmp.append(df.iloc[i].timelines['info']['frames'][k]['participantFrames'][str(0 +1)]['totalGold'])
        lst.append(tmp)
df3 = pd.DataFrame(lst, columns = columns)

# %%
df3
# Out:
#            matchId  participantId    g5    g6    g7    g8    g9
# 0    KR_6857894499              1  1541  1898  2188  2801  2966
# 1    KR_6857894499              2  1541  1898  2188  2801  2966
# 2    KR_6857894499              3  1541  1898  2188  2801  2966
# 3    KR_6857894499              4  1541  1898  2188  2801  2966
# 4    KR_6857894499              5  1541  1898  2188  2801  2966
# ..             ...            ...   ...   ...   ...   ...   ...
# 355  KR_6741424560              6  1340  1683  1868  2039  2274
# 356  KR_6741424560              7  1340  1683  1868  2039  2274
# 357  KR_6741424560              8  1340  1683  1868  2039  2274
# 358  KR_6741424560              9  1340  1683  1868  2039  2274
# 359  KR_6741424560             10  1340  1683  1868  2039  2274
#
# [360 rows x 7 columns]

# %%
df2
# Out:
#            matchId gameDuration     gameVersion    riotIdGameName  \
# 0    KR_6857894499         1747  13.24.547.9214  lIlIIllllIllIlll
# 1    KR_6857894499         1747  13.24.547.9214            손가락 없음
# 2    KR_6857894499         1747  13.24.547.9214          해양동의몰락한왕
# 3    KR_6857894499         1747  13.24.547.9214          장충동왕족발보쌈
# 4    KR_6857894499         1747  13.24.547.9214            약속한것처럼
# ..             ...          ...             ...               ...
# 355  KR_6741424560         1433  13.19.534.5972
# 356  KR_6741424560         1433  13.19.534.5972
# 357  KR_6741424560         1433  13.19.534.5972
# 358  KR_6741424560         1433  13.19.534.5972
# 359  KR_6741424560         1433  13.19.534.5972
#
#     riotIdTagline summonerLevel participantId championName champExperience  \
# 0             KR1            61             1         Yone           13483
# 1             KR1           435             2      Shyvana           20257
# ...

# %%
merge_df = pd.merge(df2, df3, on = ['matchId' , 'participantId'])

# %%
merge_df
# Out:
#            matchId  gameDuration     gameVersion    riotIdGameName  \
# 0    KR_6857894499          1747  13.24.547.9214  lIlIIllllIllIlll
# 1    KR_6857894499          1747  13.24.547.9214            손가락 없음
# 2    KR_6857894499          1747  13.24.547.9214          해양동의몰락한왕
# 3    KR_6857894499          1747  13.24.547.9214          장충동왕족발보쌈
# 4    KR_6857894499          1747  13.24.547.9214            약속한것처럼
# ..             ...           ...             ...               ...
# 355  KR_6741424560          1433  13.19.534.5972
# 356  KR_6741424560          1433  13.19.534.5972
# 357  KR_6741424560          1433  13.19.534.5972
# 358  KR_6741424560          1433  13.19.534.5972
# 359  KR_6741424560          1433  13.19.534.5972
#
#     riotIdTagline  summonerLevel  participantId championName  champExperience  \
# 0             KR1             61              1         Yone            13483
# 1             KR1            435              2      Shyvana            20257
# ...
