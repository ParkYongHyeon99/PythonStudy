# %% [markdown]
# # riot data

# %%
import requests

# %%
riot_api_key = 'RGAPI-3e834f86-cece-4e8a-9399-3b8110fcbe60'

# %%
url = f'https://kr.api.riotgames.com/lol/league/v4/challengerleagues/by-queue/RANKED_SOLO_5x5?api_key={riot_api_key}'

# %%
res = requests.get(url).json()

# %%
res.keys()
# Out:
# dict_keys(['tier', 'leagueId', 'queue', 'name', 'entries'])

# %%
res['tier']
# Out:
# 'CHALLENGER'

# %%
res['leagueId']
# Out:
# '966df365-7dea-34ca-839a-2cec050ba64a'

# %%
res['queue']
# Out:
# 'RANKED_SOLO_5x5'

# %%
res['name']
# Out:
# "Nami's Alliance"

# %%
res['entries'][0]
# Out:
# {'summonerId': 'nCBOsbBhW_-uplpAfADdOrigaXxiLFDzOp60ZCl1OdWwiq0',
#  'summonerName': '피자사줬더니올리브만빼먹는이도윤',
#  'leaguePoints': 1026,
#  'rank': 'I',
#  'wins': 250,
#  'losses': 194,
#  'veteran': True,
#  'inactive': False,
#  'freshBlood': False,
#  'hotStreak': False}

# %%
url2 = f'https://kr.api.riotgames.com/lol/summoner/v4/summoners/nCBOsbBhW_-uplpAfADdOrigaXxiLFDzOp60ZCl1OdWwiq0?api_key={riot_api_key}'

# %%
res2 = requests.get(url2).json()

# %%
res2
# Out:
# {'id': 'nCBOsbBhW_-uplpAfADdOrigaXxiLFDzOp60ZCl1OdWwiq0',
#  'accountId': '3AUFDJVgIfFmy-Xlbng6MXoxvfcNvzhL3_MnExkI__YtIYs',
#  'puuid': '2zaRDcuQiHJHlJpA6ZHz18XFBLi-iMoNTjZ6QFkpLRUElIAfwN6biTxRoGhwMDDneyDe3Lbq7ucvXQ',
#  'name': '피자사줬더니올리브만빼먹는이도윤',
#  'profileIconId': 6001,
#  'revisionDate': 1702666303000,
#  'summonerLevel': 170}

# %%
url3 = (f'https://asia.api.riotgames.com/riot/account/v1/accounts/'
        f'by-puuid/2zaRDcuQiHJHlJpA6ZHz18XFBLi-iMoNTjZ6QFkpLRUElIAfwN6biTxRoGhwMDDneyDe3Lbq7ucvXQ?api_key={riot_api_key}')

# %%
res3 = requests.get(url3).json()

# %%
res3
# Out:
# {'puuid': '2zaRDcuQiHJHlJpA6ZHz18XFBLi-iMoNTjZ6QFkpLRUElIAfwN6biTxRoGhwMDDneyDe3Lbq7ucvXQ',
#  'gameName': '피자사줬더니올리브만빼먹는이도윤',
#  'tagLine': 'KR1'}

# %%
url4 = f'https://asia.api.riotgames.com/riot/account/v1/accounts/by-riot-id/Hide%20on%20bush/KR1?api_key={riot_api_key}'

# %%
res4 = requests.get(url4).json()

# %%
res4
# Out:
# {'puuid': '3zYmziTA-HJ0rWwwYRf5NktBUgvBeSabsTFwxMdS3E19y0q9IrfZeOpiIxDPHctzBeh56yWrZ1SjDA',
#  'gameName': 'Hide on bush',
#  'tagLine': 'KR1'}

# %%
url5 = 'https://asia.api.riotgames.com/lol/match/v5/matches/by-puuid/3zYmziTA-HJ0rWwwYRf5NktBUgvBeSabsTFwxMdS3E19y0q9IrfZeOpiIxDPHctzBeh56yWrZ1SjDA/ids?start=0&count=20&api_key=RGAPI-3e834f86-cece-4e8a-9399-3b8110fcbe60'

# %%
res5 = requests.get(url5).json()

# %%
res5
# Out:
# ['KR_6823337832',
#  'KR_6823319067',
#  'KR_6823283319',
#  'KR_6823194977',
#  'KR_6823150265',
#  'KR_6823105298',
#  'KR_6822844165',
#  'KR_6822759170',
#  'KR_6821747606',
#  'KR_6804240897',
#  'KR_6804173281',
#  'KR_6804125628',
#  'KR_6804045290',
#  'KR_6802296849',
#  'KR_6802256864',
#  'KR_6802154986',
#  'KR_6801726590',
#  'KR_6801648262',
#  'KR_6800617104',
#  'KR_6800588816']

# %%
url6 = 'https://asia.api.riotgames.com/lol/match/v5/matches/KR_6823337832?api_key=RGAPI-3e834f86-cece-4e8a-9399-3b8110fcbe60'

# %%
res6 = requests.get(url6).json()

# %%
res6.keys()
# Out:
# dict_keys(['metadata', 'info'])

# %%
res6['metadata']
# Out:
# {'dataVersion': '2',
#  'matchId': 'KR_6823337832',
#  'participants': ['SJS9jDn2RvbuTdbtoDnHYd8FwjDoaFzQMq5l4rUyNdRYEyUtXmqhRxvTYazlawQysglvAntNVWAWNA',
#   'rUeXrkpmxBir9KdXENINsKqnpLNvHsOsJfce9KYRPDQGZoMDetjaiKRDLZTEpE4ug5zD5pEl9_MPzA',
#   'Da69Foj3SHD1oQRBc91gOAQ1CWE7I_nul0fZElHbLNMUYZVsOnXNC67EF-ZXMWIAR12uUKFedJQdyA',
#   'RkwnEhpFWvb8Hua9roZrAPuj0iluPmd9QCxaZfIMtEyBUkQ55hUFQklRTiMjEJZK3mVdbZbDqRphkw',
#   'L2P1-1V-_Ij7otH9NAe0DrHUhhoj77m9ylHWysTnzuBzFP6bYXDOfIT7VoLUpBiCTs56Dg0eWBbZ8A',
#   'LCp6OE5t-DDCxChN1cTCzfNfIaCPLTrQnUe7PXnyMUNDEMTln7Fb7BPXv1Jvl6HYT4MxewN8n5JMJA',
#   'PYBRXVawKFJAOunPcSmG3Ld3PppMMDOWGLuqG2-6-Zs7tZR6lPL8WQiht6HEKI2Z0Ct3LyZwtw0QLA',
#   '3zYmziTA-HJ0rWwwYRf5NktBUgvBeSabsTFwxMdS3E19y0q9IrfZeOpiIxDPHctzBeh56yWrZ1SjDA',
#   'g6ZFDIBATdHPakEKsD7IJ9NOUUNQkEv3EGu6c8pVWjSESAJHT_cyOPmyXEZiyUteuqa6G75IuaNgCA',
#   '0T6FInroq2M5fa2hetfDUgpNzOUMlzjqA3p3P64axDW6p5dxucEZSaq6xZQ_fK0s5jOEJizPpMjXmQ']}

# %%
res6['info'].keys()
# Out:
# dict_keys(['gameCreation', 'gameDuration', 'gameEndTimestamp', 'gameId', 'gameMode', 'gameName', 'gameStartTimestamp', 'gameType', 'gameVersion', 'mapId', 'participants', 'platformId', 'queueId', 'teams', 'tournamentCode'])

# %%
res6['info']['platformId']
# Out:
# 'KR'

# %%
res6['info']['queueId']
# Out:
# 420

# %%
res6['info']['teams']
# Out:
# ''

# %%
res6['info']['participants'][0]
# Out:
# {'allInPings': 0,
#  'assistMePings': 0,
#  'assists': 0,
#  'baitPings': 0,
#  'baronKills': 0,
#  'basicPings': 0,
#  'bountyLevel': 0,
#  'challenges': {'12AssistStreakCount': 0,
#   'abilityUses': 160,
#   'acesBefore15Minutes': 0,
#   'alliedJungleMonsterKills': 0,
#   'baronTakedowns': 0,
#   'blastConeOppositeOpponentCount': 0,
#   'bountyGold': 0,
#   'buffsStolen': 0,
#   'completeSupportQuestInTime': 0,
#   'controlWardTimeCoverageInRiverOrEnemyHalf': 0.37889466862900484,
#   'controlWardsPlaced': 2,
#   'damagePerMinute': 311.3595601997016,
#   'damageTakenOnTeamPercentage': 0.17737394539825307,
#   'dancedWithRiftHerald': 0,
#   'deathsByEnemyChamps': 4,
#   'dodgeSkillShotsSmallWindow': 0,
#   'doubleAces': 0,
#   'dragonTakedowns': 0,
#   'earlyLaningPhaseGoldExpAdvantage': 0,
#   'effectiveHealAndShielding': 0,
#   'elderDragonKillsWithOpposingSoul': 0,
#   'elderDragonMultikills': 0,
#   'enemyChampionImmobilizations': 6,
#   'enemyJungleMonsterKills': 0,
# ...

# %%
url7 = 'https://asia.api.riotgames.com/lol/match/v5/matches/KR_6823337832/timeline?api_key=RGAPI-3e834f86-cece-4e8a-9399-3b8110fcbe60'

# %%
res7 = requests.get(url7).json()

# %%
res7.keys()
# Out:
# dict_keys(['metadata', 'info'])

# %%
res7['metadata']
# Out:
# {'dataVersion': '2',
#  'matchId': 'KR_6823337832',
#  'participants': ['SJS9jDn2RvbuTdbtoDnHYd8FwjDoaFzQMq5l4rUyNdRYEyUtXmqhRxvTYazlawQysglvAntNVWAWNA',
#   'rUeXrkpmxBir9KdXENINsKqnpLNvHsOsJfce9KYRPDQGZoMDetjaiKRDLZTEpE4ug5zD5pEl9_MPzA',
#   'Da69Foj3SHD1oQRBc91gOAQ1CWE7I_nul0fZElHbLNMUYZVsOnXNC67EF-ZXMWIAR12uUKFedJQdyA',
#   'RkwnEhpFWvb8Hua9roZrAPuj0iluPmd9QCxaZfIMtEyBUkQ55hUFQklRTiMjEJZK3mVdbZbDqRphkw',
#   'L2P1-1V-_Ij7otH9NAe0DrHUhhoj77m9ylHWysTnzuBzFP6bYXDOfIT7VoLUpBiCTs56Dg0eWBbZ8A',
#   'LCp6OE5t-DDCxChN1cTCzfNfIaCPLTrQnUe7PXnyMUNDEMTln7Fb7BPXv1Jvl6HYT4MxewN8n5JMJA',
#   'PYBRXVawKFJAOunPcSmG3Ld3PppMMDOWGLuqG2-6-Zs7tZR6lPL8WQiht6HEKI2Z0Ct3LyZwtw0QLA',
#   '3zYmziTA-HJ0rWwwYRf5NktBUgvBeSabsTFwxMdS3E19y0q9IrfZeOpiIxDPHctzBeh56yWrZ1SjDA',
#   'g6ZFDIBATdHPakEKsD7IJ9NOUUNQkEv3EGu6c8pVWjSESAJHT_cyOPmyXEZiyUteuqa6G75IuaNgCA',
#   '0T6FInroq2M5fa2hetfDUgpNzOUMlzjqA3p3P64axDW6p5dxucEZSaq6xZQ_fK0s5jOEJizPpMjXmQ']}

# %%
res7['info'].keys()
# Out:
# dict_keys(['frameInterval', 'frames', 'gameId', 'participants'])

# %%
res7['info']['participants']
# Out:
# [{'participantId': 1,
#   'puuid': 'SJS9jDn2RvbuTdbtoDnHYd8FwjDoaFzQMq5l4rUyNdRYEyUtXmqhRxvTYazlawQysglvAntNVWAWNA'},
#  {'participantId': 2,
#   'puuid': 'rUeXrkpmxBir9KdXENINsKqnpLNvHsOsJfce9KYRPDQGZoMDetjaiKRDLZTEpE4ug5zD5pEl9_MPzA'},
#  {'participantId': 3,
#   'puuid': 'Da69Foj3SHD1oQRBc91gOAQ1CWE7I_nul0fZElHbLNMUYZVsOnXNC67EF-ZXMWIAR12uUKFedJQdyA'},
#  {'participantId': 4,
#   'puuid': 'RkwnEhpFWvb8Hua9roZrAPuj0iluPmd9QCxaZfIMtEyBUkQ55hUFQklRTiMjEJZK3mVdbZbDqRphkw'},
#  {'participantId': 5,
#   'puuid': 'L2P1-1V-_Ij7otH9NAe0DrHUhhoj77m9ylHWysTnzuBzFP6bYXDOfIT7VoLUpBiCTs56Dg0eWBbZ8A'},
#  {'participantId': 6,
#   'puuid': 'LCp6OE5t-DDCxChN1cTCzfNfIaCPLTrQnUe7PXnyMUNDEMTln7Fb7BPXv1Jvl6HYT4MxewN8n5JMJA'},
#  {'participantId': 7,
#   'puuid': 'PYBRXVawKFJAOunPcSmG3Ld3PppMMDOWGLuqG2-6-Zs7tZR6lPL8WQiht6HEKI2Z0Ct3LyZwtw0QLA'},
#  {'participantId': 8,
#   'puuid': '3zYmziTA-HJ0rWwwYRf5NktBUgvBeSabsTFwxMdS3E19y0q9IrfZeOpiIxDPHctzBeh56yWrZ1SjDA'},
#  {'participantId': 9,
# ...

# %%
res7['info']['frames'][10].keys()
# Out:
# dict_keys(['events', 'participantFrames', 'timestamp'])

# %% [markdown]
# ## 1. puu_id를 찾는다. (league-v4 or account v1 or summoner v4)
# ## 2. puu_id를 통해 match_id를 찾는다 (match v5)
# ## 3. match_id를 통해 matches, timeline 데이터를 찾아온다. (match v5)

# %%
url = 'https://kr.api.riotgames.com/lol/league/v4/challengerleagues/by-queue/RANKED_SOLO_5x5?api_key=RGAPI-3e834f86-cece-4e8a-9399-3b8110fcbe60'

# %%
res = requests.get(url).json()

# %%
lst = [res['entries'][i]['summonerId']  for i in range(len(res['entries']))]

# %%
lst = []
for i in range(len(res['entries'])):
    lst.append(res['entries'][i]['summonerId'])

# %%
lst
# Out:
# ['gwwnYMLoaYza0V8OutrnSfTjAaKg6PKzko-YRUV7GTkXKUiTkfx6KatFag',
#  'uqNYjgQNwhfbBVcWACGWaR3ppCG-mHaJTX7FDeDMhYUpOirul58ENYagAA',
#  'DInIRgySiPNvrm71diPgUVlbe86UJqdO6vnB0JAcQcalWwc',
#  'yQuAvlp3WZUv2KR7KFMIf-QnVD_VjV6lyVJOROh51pZ3uzY',
#  'EqEenQkmBYK8TdD3jhkUYtk0mbxq8Maqaa15__OinAwgOiC49AIUieaJYA',
#  'C4Dh2BLOril4xKOBa0nAKtWghW_qp28DJjCXQzWUy6_NqSZN',
#  'uGeOJKEfCWjPw8a5rwGEiGZA8eLlIkOy28S15ZFBt80Dzw',
#  'ifERk4HQHA-eIoHP7CniKDMh5J5xCTpTuMedk-oQc8MvHz4',
#  'l99DDHQcGRpBlHDjqLhJKh0ZkyKyVsITGHpfsEdq3gWhON0',
#  'myRuIVAAybF4M3WHfwpJYD3w4ZGp3nnaiM9lthEyPRaOr7i9zv2GADtolw',
#  'DU5nRyqYPhuWPRMVzO2p1KTyPHiHdmKYnxw1Dgtw6N1s8Lo',
#  'rSISq-RjUiY7Iae3i5QcWiLud7l-v25xCdCqfvnI4xWcoWc',
#  '-wqQunlKc7CMdMGoQdy9nn_W--Ull7ULw0junCsk4O0c5kE',
#  'B2g5LfiQtutaANQJNMhwE_Gfn9PuXPsfngJqGVMKSqdjqEE',
#  'ttWo_sNQZWlUYD24NXkQE7UCJ8tJs8FvOkD0upb7ymZFVrxBpdxVZU_-eg',
#  'MSpPynEtAbwLSUqaoUryZZm19XPlcdWqFoxDsgmOAEYkPr_aQu2Dlm4hiA',
#  'FgQtJDlWZZy9Ew7gYme-5LzAWrKbyz4X9YrPTKQKXaHXw1KiqnLwqseeQw',
# ...

# %%
summoner_id = lst[0]

# %%
riot_api_key = 'RGAPI-3e834f86-cece-4e8a-9399-3b8110fcbe60'

# %%
url2 = f'https://kr.api.riotgames.com/lol/summoner/v4/summoners/{summoner_id}?api_key={riot_api_key}'

# %%
url2 = f'https://kr.api.riotgames.com/lol/summoner/v4/summoners/{summoner_id}?api_key={riot_api_key}'

# %%
res2 = requests.get(url2).json()

# %%
puuid = res2['puuid']

# %%
puuid
# Out:
# '-w922u7ZMEMRZnrDNuMaSFoSUTfVahd6DAWZDttoW0q8FbDLuElWAhtp7MqNr1Y8MhzwGr_1SXf4OA'

# %%
url3 = f'https://asia.api.riotgames.com/lol/match/v5/matches/by-puuid/{puuid}/ids?start=0&count=20&api_key={riot_api_key}'

# %%
url3 = f'https://asia.api.riotgames.com/lol/match/v5/matches/by-puuid/{puuid}/ids?start=0&count=20&api_key={riot_api_key}'

# %%
res3 = requests.get(url3).json()

# %%
res3
# Out:
# ['KR_6850466089',
#  'KR_6850398036',
#  'KR_6850327470',
#  'KR_6850241673',
#  'KR_6850182298',
#  'KR_6850130591',
#  'KR_6850088614',
#  'KR_6850024399',
#  'KR_6846379241',
#  'KR_6844782096',
#  'KR_6840762913',
#  'KR_6840724995',
#  'KR_6840616400',
#  'KR_6840567012',
#  'KR_6840505901',
#  'KR_6840465727',
#  'KR_6835091101',
#  'KR_6835071688',
#  'KR_6835066243',
#  'KR_6835042828']

# %%
match_id = res3[0]

# %%
match_id
# Out:
# 'KR_6850466089'

# %%
url4 = f'https://asia.api.riotgames.com/lol/match/v5/matches/{match_id}?api_key={riot_api_key}'

# %%
url4 = f'https://asia.api.riotgames.com/lol/match/v5/matches/{match_id}?api_key={riot_api_key}

# %%
res4 = requests.get(url4).json()

# %%
res4
# Out:
# {'metadata': {'dataVersion': '2',
#   'matchId': 'KR_6850466089',
#   'participants': ['wac19XhH0nIFEOD0tSMwwD1x-8wQTBaPSeHIYvmcCE5YF8cpuYO02iGiHWS6klejaxZQh06t4lH9-w',
#    '6rQA56JMaJxgxBlh5wiqGO9E5QpV7iPTseR-IU1Hx-VhxpjhaAgIR49rEisxRK4Kb48qq_WhOx3WgA',
#    'VpQ7RUTWOdqIVNX7vBAKGjhk6i69Kzsr0xVUZ0Fe4gKWCPtqgYT3y3SW8oIUIV4UfdDwGC2FF1jHRA',
#    'Oc0y7GHEULn8E6HCMlWmQysmwc30yVpSeOITf5AJVLbMzeKaBxL8tKPzB012u00acBc3PESFdSZjkw',
#    'Y0cFqBbU8-RBOEXZ7sMSSidCPEBQjyWVwzvu2ODtkb0fgVPT0tboCPdRoBAptIRGgbjEAaPVd0FwkQ',
#    'cuHZ_AYME5TUns8Y9-4ORXkV6XHKi08QF3iHlienst_wYNAYaoUC9nhS1oVw_h2Mz7K_9yKCxeqZNg',
#    'amCx8RoB0cH7pcaNU-5kjaWZHb0_Q2Z-ysDlby6bm_7HQ_o3JrUnYHX8M_5BZhkBRgNugGbYbb1mdQ',
#    '-w922u7ZMEMRZnrDNuMaSFoSUTfVahd6DAWZDttoW0q8FbDLuElWAhtp7MqNr1Y8MhzwGr_1SXf4OA',
#    'M51e6sspUQKD_-Vhb757KMQepSxOgpJOHpsQQHGm3FrKPX-q3nO4ptZmeuHDxHa7e6GPfn-UEwCzAA',
#    'VD3TNEErjzAVPV9fW1sCoW1Evm9D8VOqK8rpvKRIeP7INGcSXDe1jqAUIPkYuA9BUkw5ZdycJZuV0g']},
#  'info': {'gameCreation': 1702636049838,
# ...

# %% [markdown]
# # 함수 만들기

# %% [markdown]
# # 3개의 함수 (본인 아이디가 있는경우 본인 아이디로)
#
# # account v1을 통해 game아이디#태그 -> PUUID 얻는 함수
# # puuid를 통해 match_id를 얻어내는 함수 (20개중 한개만 호출)
# # match_id를 통해 matches와 timeline 데이터를 얻어내는 함수

# %%
api_key = 'RGAPI-3e834f86-cece-4e8a-9399-3b8110fcbe60'

# %%
nickname = '건강한코어'
tag = 'KR1'

# %%
def get_puuid(nickname,tag):
    url = f'https://asia.api.riotgames.com/riot/account/v1/accounts/by-riot-id/{nickname}/{tag}?api_key={api_key}'
    res = requests.get(url).json()
    puuid = res['puuid']
    return puuid

# %%
puuid = get_puuid(nickname,tag)

# %%
puuid
# Out:
# '-aieWUAi82ljjQw4wxEFAIZkYmiZ3S0LM870RN0IABaGYOUD17C9MJ5SyLmysDjHXtSKjrxrvDjcTg'

# %%
def get_match_id(puuid):
    url = f'https://asia.api.riotgames.com/lol/match/v5/matches/by-puuid/{puuid}/ids?start=0&count=20&api_key={api_key}'
    match_list = requests.get(url).json()
    return match_list

# %%
match_list = get_match_id(puuid)

# %%
match_list
# Out:
# ['KR_6856268527',
#  'KR_6856259178',
#  'KR_6855429308',
#  'KR_6855408149',
#  'KR_6855143923',
#  'KR_6851465223',
#  'KR_6851414842',
#  'KR_6850283715',
#  'KR_6849819787',
#  'KR_6849804456',
#  'KR_6848116093',
#  'KR_6847152488',
#  'KR_6846473276',
#  'KR_6844862104',
#  'KR_6843837789',
#  'KR_6842563982',
#  'KR_6842069779',
#  'KR_6841686241',
#  'KR_6840215357',
#  'KR_6840161029']

# %%
matchid
# Out:
# 'KR_6840161029'

# %%
def get_matches_timelines(matchid):
    url1 = f'https://asia.api.riotgames.com/lol/match/v5/matches/{matchid}?api_key={api_key}'
    url2 = f'https://asia.api.riotgames.com/lol/match/v5/matches/{matchid}/timeline?api_key={api_key}'
    matches = requests.get(url1).json()
    timelines = requests.get(url2).json()
    return matches,timelines

# %%
from tqdm import tqdm
import pandas as pd

# %%
api_key = 'RGAPI-3e834f86-cece-4e8a-9399-3b8110fcbe60'
nickname = '건강한코어'
tag = 'KR1'
puuid = get_puuid(nickname,tag)
match_list = get_match_id(puuid)
data_list = []

for matchid in tqdm(match_list):
    matches,timelines = get_matches_timelines(matchid)
    data_list.append([matchid,matches,timelines])
# Out:
# 100%|██████████| 20/20 [00:59<00:00,  2.97s/it]

# %%
df = pd.DataFrame(data_list,columns = ['match_id','matches','timelines'])

# %%
df.iloc[0].matches['info']['participants'][1]['kills']
# Out:
# 26

# %%
len(df)
# Out:
# 20

# %%
df
# Out:
#          match_id                                            matches  \
# 0   KR_6856268527  {'metadata': {'dataVersion': '2', 'matchId': '...
# 1   KR_6856259178  {'metadata': {'dataVersion': '2', 'matchId': '...
# 2   KR_6855429308  {'metadata': {'dataVersion': '2', 'matchId': '...
# 3   KR_6855408149  {'metadata': {'dataVersion': '2', 'matchId': '...
# 4   KR_6855143923  {'metadata': {'dataVersion': '2', 'matchId': '...
# 5   KR_6851465223  {'metadata': {'dataVersion': '2', 'matchId': '...
# 6   KR_6851414842  {'metadata': {'dataVersion': '2', 'matchId': '...
# 7   KR_6850283715  {'metadata': {'dataVersion': '2', 'matchId': '...
# 8   KR_6849819787  {'metadata': {'dataVersion': '2', 'matchId': '...
# 9   KR_6849804456  {'metadata': {'dataVersion': '2', 'matchId': '...
# 10  KR_6848116093  {'metadata': {'dataVersion': '2', 'matchId': '...
# 11  KR_6847152488  {'metadata': {'dataVersion': '2', 'matchId': '...
# 12  KR_6846473276  {'metadata': {'dataVersion': '2', 'matchId': '...
# ...

# %%
matchid,championname,kills,deaths,assists
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 matchid,championname,kills,deaths,assists
#
# NameError: name 'championname' is not defined

# %%
kda = []
for i in range(len(df)):
    participants = df.iloc[i]['matches']['info']['participants']
    for j in range(len(participants)):
        tmp = []
        tmp.append(df.iloc[i].match_id)
        tmp.append(participants[j]['championName'])
        tmp.append(participants[j]['kills'])
        tmp.append(participants[j]['deaths'])
        tmp.append(participants[j]['assists'])
        kda.append(tmp)

# %%
df2 = pd.DataFrame(kda,columns = ['match_id','championName','kills','deaths','assists'])

# %%
df2
# Out:
#           match_id championName  kills  deaths  assists
# 0    KR_6856268527        Annie     10       8       37
# 1    KR_6856268527     Katarina     26      10       23
# 2    KR_6856268527     Nautilus      1      10       38
# 3    KR_6856268527       Aatrox     20       6       16
# 4    KR_6856268527     Tristana      7      13       18
# ..             ...          ...    ...     ...      ...
# 171  KR_6840161029        Kaisa      2       9        3
# 172  KR_6840161029         Yone      5       7        2
# 173  KR_6840161029     Volibear      1       7        6
# 174  KR_6840161029       Darius      8       1       12
# 175  KR_6840161029        Varus     12       1        7
#
# [176 rows x 5 columns]

# %%
df2
# Out:
#             gameId gameDuration     gameVersion riotIdGameName riotIdTagline  \
# 0    KR_6810377664         1210  13.23.544.5515         GRF 도란           KR1
# 1    KR_6810377664         1210  13.23.544.5515        모시모시강아지           KR1
# 2    KR_6810377664         1210  13.23.544.5515            아망스           KR1
# 3    KR_6810377664         1210  13.23.544.5515          Fairy           요 정
# 4    KR_6810377664         1210  13.23.544.5515       ArinArin           KR1
# ..             ...          ...             ...            ...           ...
# 195  KR_6827606761         1809  13.23.544.5515        Melonik         melon
# 196  KR_6827606761         1809  13.23.544.5515       데이지야 밥먹자           KR1
# 197  KR_6827606761         1809  13.23.544.5515        kuluomi           KR1
# 198  KR_6827606761         1809  13.23.544.5515          Riris         Riris
# 199  KR_6827606761         1809  13.23.544.5515        kbj0628           KR1
#
# ...
